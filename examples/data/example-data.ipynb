# %% [markdown]
# Target needs to be numerical for most sklrean mtds (as of writing).
# This is probably good practice in gerneal

# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Age     Workclass  Fnlwgt  Education  Education-num      Marital-status  \
# 0   37       Private  193106  Bachelors             13       Never-married
# 1   56  Self-emp-inc  216636       12th              8  Married-civ-spouse
# 2   53       Private  126977    HS-grad              9           Separated
# 3   72       Private  205343       11th              7             Widowed
# 4   46     State-gov  106705    Masters             14       Never-married
#
#         Occupation   Relationship   Race     Sex  Capital-gain  Capital-loss  \
# 0            Sales  Not-in-family  White  Female             0             0
# 1  Exec-managerial        Husband  White    Male             0          1651
# 2     Craft-repair  Not-in-family  White    Male             0             0
# 3     Adm-clerical      Unmarried  White  Female             0             0
# 4  Exec-managerial  Not-in-family  White  Female             0             0
#
#    Hours-per-week Native-country Income
# 0              30  United-States  <=50K
# 1              40  United-States  <=50K
# 2              35  United-States  <=50K
# 3              40  United-States  <=50K
# 4              38  United-States  <=50K

# %%
data["Income"] = data["Income"].apply(lambda x: 1 if x == "<=50K" else 0)

# %%
data.head()
# Out:
#    Age     Workclass  Fnlwgt  Education  Education-num      Marital-status  \
# 0   37       Private  193106  Bachelors             13       Never-married
# 1   56  Self-emp-inc  216636       12th              8  Married-civ-spouse
# 2   53       Private  126977    HS-grad              9           Separated
# 3   72       Private  205343       11th              7             Widowed
# 4   46     State-gov  106705    Masters             14       Never-married
#
#         Occupation   Relationship   Race     Sex  Capital-gain  Capital-loss  \
# 0            Sales  Not-in-family  White  Female             0             0
# 1  Exec-managerial        Husband  White    Male             0          1651
# 2     Craft-repair  Not-in-family  White    Male             0             0
# 3     Adm-clerical      Unmarried  White  Female             0             0
# 4  Exec-managerial  Not-in-family  White  Female             0             0
#
#    Hours-per-week Native-country  Income
# 0              30  United-States       1
# 1              40  United-States       1
# 2              35  United-States       1
# 3              40  United-States       1
# 4              38  United-States       1

# %%
# write to file
data.to_csv("./data.csv")
